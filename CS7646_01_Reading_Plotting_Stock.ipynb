# %% [markdown]
# <a href="https://colab.research.google.com/github/jlee5814/ReadingStockData/blob/main/CS7646_01_Reading_Plotting_Stock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/Drive")
# Out:
# Mounted at /content/Drive

# %%
import pandas as pd
import matplotlib.pyplot as plt

#path = "/content/Drive/MyDrive/CS 7646 ML4T/AAPL.csv"
#df = pd.read_csv(path)

# %%
#def get_mean_volume(symbol):
#  """Return the maximum closing value for stock indicated by symbol.
#
#  Note: Data for a stock is stored in file: data/<symbol>/csv
#  
#  Stock prices reflect 1Q22 
#  """
#  df = pd.read_csv("/content/Drive/MyDrive/CS 7646 ML4T/{}.csv".format(symbol)) #read in data
#  return df["Volume"].mean()

def test_run():
  """Function called by Test Run."""
  df = pd.read_csv("/content/Drive/MyDrive/CS 7646 ML4T/AAPL.csv") #read in data
  #Adjusted Closing Price is the stock price that takes into account corporate actions (e.g., stock splits) and distributions (e.g., dividends issued)
  df[["Close", "Adj Close"]].plot()
  plt.ylabel("Price")
  plt.xlabel("Day")
  plt.show() #must be called to show plots

  # for symbol in ["AAPL", "IBM"]:
 
  #   print("Mean Volume:")
  #   print(symbol, round(get_mean_volume(symbol),2))
  #   print(" ")

if __name__ == "__main__":
  test_run()
